# %%
import requests
import json
import pprint

# %%
api_key='1bH1i6hqL0TXbaFy8Jm4O7O5brL-iPCC5-0MvC_Wm18KDkFM0vD51t7EuuSfZeQF_i2FxDSZFwUZBP2mCsV9McVCUustTrkIGVISF4p-ZJLkwLL_XY_lEhLmeBzaXHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'restaurants','location':'85286'}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)

# proceed only if the status code is 200
# print('The status code is {}'.format(req.status_code))

# %%
# printing the text from the response 
json.loads(req.text)
# Out:
# {'businesses': [{'id': 'CZKHXlDuy3IagC2W881fyA',
#    'alias': 'the-brickyard-downtown-chandler-3',
#    'name': 'The Brickyard Downtown',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eRDBRbW2Sj7tiuK3fyQjrg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-brickyard-downtown-chandler-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 480,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.30201, 'longitude': -111.84252},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '85 W Boston St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['85 W Boston St', 'Chandler, AZ 85225']},
#    'phone': '+14809631373',
#    'display_phone': '(480) 963-1373',
#    'distance': 3709.260541098345},
#   {'id': 'fXz8-8y0n5mwXRk98G9TMA',
#    'alias': 'cherish-farm-fresh-eatery-chandler',
#    'name': 'Cherish Farm Fresh Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LEYIV-yMEpq47BnF6Zq4yQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cherish-farm-fresh-eatery-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 103,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.26134, 'longitude': -111.8855},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2551 W Queen Creek Rd',
#     'address2': 'Ste 4',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2551 W Queen Creek Rd',
#      'Ste 4',
#      'Chandler, AZ 85248']},
#    'phone': '+14803507245',
#    'display_phone': '(480) 350-7245',
#    'distance': 4889.293352853556},
#   {'id': 'UaqpGfgM5fJBZC9p-zqISg',
#    'alias': 'johnnys-greek-and-burger-bar-chandler-4',
#    'name': "Johnny's Greek & Burger Bar",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_G_uWlwOU3ioorBRvKxM4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johnnys-greek-and-burger-bar-chandler-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 31,
#    'categories': [{'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.2341439, 'longitude': -111.8583688},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4975 S Alma School Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4975 S Alma School Rd', 'Chandler, AZ 85225']},
#    'phone': '+14805341884',
#    'display_phone': '(480) 534-1884',
#    'distance': 4456.705298679878},
#   {'id': '-CfFjcCcGGDM9MVH_d42RQ',
#    'alias': 'the-ivy-chandler',
#    'name': 'The Ivy',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5JWwoAiYFlKcDiWDr6Vo_w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-ivy-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 476,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'greek', 'title': 'Greek'},
#     {'alias': 'lounges', 'title': 'Lounges'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.27724, 'longitude': -111.87427},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1890 W Germann Rd',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85286',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1890 W Germann Rd', 'Ste 1', 'Chandler, AZ 85286']},
#    'phone': '+14806996189',
#    'display_phone': '(480) 699-6189',
#    'distance': 3874.325672456274},
#   {'id': 'rcTGlKMPHFDQbzkdZFK-sw',
#    'alias': 'farmboy-market-meats-sandwiches-chandler-2',
#    'name': 'Farmboy Market, Meats, Sandwiches',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x78bQGzZK6y17lUgUhZJbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/farmboy-market-meats-sandwiches-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 108,
#    'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.2616451, 'longitude': -111.8634891},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1075 W Queen Creek Rd',
#     'address2': 'Ste 1',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1075 W Queen Creek Rd',
#      'Ste 1',
#      'Chandler, AZ 85248']},
#    'phone': '+14803612153',
#    'display_phone': '(480) 361-2153',
#    'distance': 2681.982036152666},
#   {'id': '2aeZ9Xm_mjia11jf1pg7QA',
#    'alias': 'green-corner-restaurant-chandler-3',
#    'name': 'Green Corner Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xqHVsN049nZTE5TBk7qTMA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/green-corner-restaurant-chandler-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 206,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'},
#     {'alias': 'greek', 'title': 'Greek'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.2616425, 'longitude': -111.8635409},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1065 W Queen Creek Rd',
#     'address2': 'Ste 2',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1065 W Queen Creek Rd',
#      'Ste 2',
#      'Chandler, AZ 85248']},
#    'phone': '+14805537011',
#    'display_phone': '(480) 553-7011',
#    'distance': 2671.59275081591},
#   {'id': '-fZ4jE_7FKos0MQvMqoj5Q',
#    'alias': 'culinary-dropout-gilbert-4',
#    'name': 'Culinary Dropout',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Gse0akUPdo_bFXRo8_1pkQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/culinary-dropout-gilbert-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 98,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.3569301, 'longitude': -111.7895751},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '383 N Gilbert Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Gilbert',
#     'zip_code': '85234',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['383 N Gilbert Rd', 'Gilbert, AZ 85234']},
#    'phone': '+14804183980',
#    'display_phone': '(480) 418-3980',
#    'distance': 10520.835790435194},
#   {'id': 'JGbQOdAAqxEKlyJy07omuw',
#    'alias': 'civic-market-chandler',
#    'name': 'Civic Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/scSNIth8v2U5-qtlpb2cYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/civic-market-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 15,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.3004818489723,
#     'longitude': -111.840002909303},
#    'transactions': [],
#    'location': {'address1': '201 S Washington St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['201 S Washington St', 'Chandler, AZ 85225']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3484.8129626252367},
#   {'id': 'QwPt--ZmXlSHq_UhUYpIYw',
#    'alias': 'ghett-yo-taco-chandler',
#    'name': 'Ghett Yo Taco',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T9fHMIqhzXbcJ61PsPTjZg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ghett-yo-taco-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 264,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.29987, 'longitude': -111.84258},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '241 S Oregon St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['241 S Oregon St', 'Chandler, AZ 85225']},
#    'phone': '+14807269654',
#    'display_phone': '(480) 726-9654',
#    'distance': 3470.6312648576245},
#   {'id': '52yWGkwnrQXIjvuMjYxsiA',
#    'alias': 'not-your-typical-deli-gilbert',
#    'name': 'Not Your Typical Deli',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RYG8jPlPCtAjGs7PxeyGug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/not-your-typical-deli-gilbert?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 520,
#    'categories': [{'alias': 'delis', 'title': 'Delis'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'cuban', 'title': 'Cuban'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.328922, 'longitude': -111.795453},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1166 South Gilbert Rd',
#     'address2': 'Ste 101',
#     'address3': None,
#     'city': 'Gilbert',
#     'zip_code': '85296',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1166 South Gilbert Rd',
#      'Ste 101',
#      'Gilbert, AZ 85296']},
#    'phone': '+14807941116',
#    'display_phone': '(480) 794-1116',
#    'distance': 7468.977902133951},
#   {'id': '_H4GXECi4nHfJTz4dsQV_w',
#    'alias': 'ritas-burritos-chandler',
#    'name': "Rita's Burritos",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sM7KoOGe_hIGoCaX16gmFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ritas-burritos-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 281,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.246637, 'longitude': -111.84268},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '4040 S Arizona Ave',
#     'address2': 'Ste 17',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4040 S Arizona Ave', 'Ste 17', 'Chandler, AZ 85248']},
#    'phone': '+14804049128',
#    'display_phone': '(480) 404-9128',
#    'distance': 2704.683918527783},
#   {'id': 'U4OLUFb9VxMmpMXm1ZF-cQ',
#    'alias': 'pho-chandler-chandler',
#    'name': 'Pho Chandler',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eDW_BuE0jWui79fnJwCqrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 527,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.24675, 'longitude': -111.83921},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4055 S Arizona Ave',
#     'address2': 'Ste 8',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4055 S Arizona Ave', 'Ste 8', 'Chandler, AZ 85248']},
#    'phone': '+14808959090',
#    'display_phone': '(480) 895-9090',
#    'distance': 2638.4978300426837},
#   {'id': 'dsvLGvwI8Q3PSLWPMBadMw',
#    'alias': 'st-amand-kitchen-and-cocktails-chandler',
#    'name': 'St. Amand Kitchen and Cocktails',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WJG80nfMj-tYssQnD716cw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/st-amand-kitchen-and-cocktails-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 5,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.2475806926958,
#     'longitude': -111.865434303524},
#    'transactions': [],
#    'location': {'address1': '3990 S Alma School Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['3990 S Alma School Rd', 'Chandler, AZ 85248']},
#    'phone': '+14807825550',
#    'display_phone': '(480) 782-5550',
#    'distance': 3868.9767259434952},
#   {'id': 'Rn2zXbZJab8mPUz8aYdOtQ',
#    'alias': 'tryst-cafe-chandler-chandler-2',
#    'name': 'Tryst Cafe Chandler',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/J8j496D1PbqXS6HjZ2Oa-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tryst-cafe-chandler-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 106,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.2403644482708,
#     'longitude': -111.78929276642},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '4205 S Gilbert Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85249',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4205 S Gilbert Rd', 'Chandler, AZ 85249']},
#    'phone': '+14806561011',
#    'display_phone': '(480) 656-1011',
#    'distance': 4928.210878992833},
#   {'id': 'HujfG5PyOqn5bPsoxkgSiw',
#    'alias': 'bkd-backyard-joint-chandler',
#    'name': 'BKD Backyard Joint',
#    'image_url': '',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkd-backyard-joint-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 1,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.2932987090176,
#     'longitude': -111.824992170089},
#    'transactions': [],
#    'location': {'address1': '980 E Pecos Rd',
#     'address2': 'Ste 5',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['980 E Pecos Rd', 'Ste 5', 'Chandler, AZ 85225']},
#    'phone': '+14809352537',
#    'display_phone': '(480) 935-2537',
#    'distance': 2739.5871327369096},
#   {'id': 'HYhbeLznSWEl6JIYTllVUA',
#    'alias': 'stone-and-vine-urban-italian-chandler-2',
#    'name': 'Stone & Vine Urban Italian',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HQNfxs9czSQIlOnbXSaV6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stone-and-vine-urban-italian-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 378,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.2608865864458,
#     'longitude': -111.859443623372},
#    'transactions': ['delivery', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1035 W Queen Creek Rd',
#     'address2': 'Ste 103',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85248',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['1035 W Queen Creek Rd',
#      'Ste 103',
#      'Chandler, AZ 85248']},
#    'phone': '+14806597438',
#    'display_phone': '(480) 659-7438',
#    'distance': 2621.6555403207935},
#   {'id': 'kDo4Lu9V3EKJ0QXzIQ1t0w',
#    'alias': 'sashas-kitchen-and-cocktails-chandler',
#    'name': "Sasha's Kitchen & Cocktails",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TD1mFz9Fb0HBSbepnKL15w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sashas-kitchen-and-cocktails-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 281,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.30201, 'longitude': -111.84242},
#    'transactions': ['delivery', 'restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '81 W Boston St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['81 W Boston St', 'Chandler, AZ 85225']},
#    'phone': '+14802847447',
#    'display_phone': '(480) 284-7447',
#    'distance': 3696.7979679634295},
#   {'id': '1GXTRFzsANkhkRIivqMtuQ',
#    'alias': 'the-local-chandler-chandler',
#    'name': 'The Local Chandler',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9OOWfQySPRlay9-c0QwGxg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-local-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 157,
#    'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'tacos', 'title': 'Tacos'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.3004263644627,
#     'longitude': -111.842268034816},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '55 W Chicago St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85225',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['55 W Chicago St', 'Chandler, AZ 85225']},
#    'phone': '+14806999104',
#    'display_phone': '(480) 699-9104',
#    'distance': 3522.732729303816},
#   {'id': 'x4WNvN5wtMb8KVvYZOsLag',
#    'alias': 'grubstak-chandler-chandler',
#    'name': 'Grubstak - Chandler',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/g1MPTR5lf1WeNelPlLDyFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grubstak-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 66,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.2405529, 'longitude': -111.7892151},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4165 S Gilbert Rd',
#     'address2': 'Ste 5',
#     'address3': '',
#     'city': 'Chandler',
#     'zip_code': '85249',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4165 S Gilbert Rd', 'Ste 5', 'Chandler, AZ 85249']},
#    'phone': '+14804543299',
#    'display_phone': '(480) 454-3299',
#    'distance': 4853.628201745834},
#   {'id': 'WHiND6UPxr6WzgGhz2E91Q',
#    'alias': 'hash-kitchen-chandler-4',
#    'name': 'Hash Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CCUI5nU8JFcSQ6SAJCJApQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hash-kitchen-chandler-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 865,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.3199317579525,
#     'longitude': -111.890247389674},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2855 W Ray Rd',
#     'address2': 'Ste 3',
#     'address3': None,
#     'city': 'Chandler',
#     'zip_code': '85224',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2855 W Ray Rd', 'Ste 3', 'Chandler, AZ 85224']},
#    'phone': '+14809094270',
#    'display_phone': '(480) 909-4270',
#    'distance': 7700.913701367345}],
#  'total': 2700,
#  'region': {'center': {'longitude': -111.83326721191406,
#    'latitude': 33.26965211363515}}}

# %%
# Out:
# ('{"businesses": [{"id": "CZKHXlDuy3IagC2W881fyA", "alias": '
#  '"the-brickyard-downtown-chandler-3", "name": "The Brickyard Downtown", '
#  '"image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/eRDBRbW2Sj7tiuK3fyQjrg/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/the-brickyard-downtown-chandler-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 480, "categories": [{"alias": "cocktailbars", "title": '
#  '"Cocktail Bars"}, {"alias": "newamerican", "title": "American (New)"}], '
#  '"rating": 4.5, "coordinates": {"latitude": 33.30201, "longitude": '
#  '-111.84252}, "transactions": [], "price": "$$", "location": {"address1": "85 '
#  'W Boston St", "address2": "", "address3": "", "city": "Chandler", '
#  '"zip_code": "85225", "country": "US", "state": "AZ", "display_address": ["85 '
#  'W Boston St", "Chandler, AZ 85225"]}, "phone": "+14809631373", '
#  '"display_phone": "(480) 963-1373", "distance": 3709.260541098345}, {"id": '
#  '"fXz8-8y0n5mwXRk98G9TMA", "alias": "cherish-farm-fresh-eatery-chandler", '
#  '"name": "Cherish Farm Fresh Eatery", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/LEYIV-yMEpq47BnF6Zq4yQ/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/cherish-farm-fresh-eatery-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 103, "categories": [{"alias": "newamerican", "title": '
#  '"American (New)"}, {"alias": "breakfast_brunch", "title": "Breakfast & '
#  'Brunch"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 4.5, '
#  '"coordinates": {"latitude": 33.26134, "longitude": -111.8855}, '
#  '"transactions": [], "price": "$$", "location": {"address1": "2551 W Queen '
#  'Creek Rd", "address2": "Ste 4", "address3": "", "city": "Chandler", '
#  '"zip_code": "85248", "country": "US", "state": "AZ", "display_address": '
#  '["2551 W Queen Creek Rd", "Ste 4", "Chandler, AZ 85248"]}, "phone": '
#  '"+14803507245", "display_phone": "(480) 350-7245", "distance": '
#  '4889.293352853556}, {"id": "UaqpGfgM5fJBZC9p-zqISg", "alias": '
#  '"johnnys-greek-and-burger-bar-chandler-4", "name": "Johnny\'s Greek & Burger '
#  'Bar", "image_url": '
#  '"https://s3-media4.fl.yelpcdn.com/bphoto/_G_uWlwOU3ioorBRvKxM4Q/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/johnnys-greek-and-burger-bar-chandler-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 31, "categories": [{"alias": "greek", "title": "Greek"}, '
#  '{"alias": "burgers", "title": "Burgers"}], "rating": 4.5, "coordinates": '
#  '{"latitude": 33.2341439, "longitude": -111.8583688}, "transactions": '
#  '["pickup", "delivery"], "price": "$$", "location": {"address1": "4975 S Alma '
#  'School Rd", "address2": null, "address3": "", "city": "Chandler", '
#  '"zip_code": "85225", "country": "US", "state": "AZ", "display_address": '
#  '["4975 S Alma School Rd", "Chandler, AZ 85225"]}, "phone": "+14805341884", '
#  '"display_phone": "(480) 534-1884", "distance": 4456.705298679878}, {"id": '
#  '"-CfFjcCcGGDM9MVH_d42RQ", "alias": "the-ivy-chandler", "name": "The Ivy", '
#  '"image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/5JWwoAiYFlKcDiWDr6Vo_w/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/the-ivy-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 476, "categories": [{"alias": "mediterranean", "title": '
#  '"Mediterranean"}, {"alias": "greek", "title": "Greek"}, {"alias": "lounges", '
#  '"title": "Lounges"}], "rating": 4.0, "coordinates": {"latitude": 33.27724, '
#  '"longitude": -111.87427}, "transactions": ["pickup", '
#  '"restaurant_reservation"], "price": "$$", "location": {"address1": "1890 W '
#  'Germann Rd", "address2": "Ste 1", "address3": "", "city": "Chandler", '
#  '"zip_code": "85286", "country": "US", "state": "AZ", "display_address": '
#  '["1890 W Germann Rd", "Ste 1", "Chandler, AZ 85286"]}, "phone": '
#  '"+14806996189", "display_phone": "(480) 699-6189", "distance": '
#  '3874.325672456274}, {"id": "rcTGlKMPHFDQbzkdZFK-sw", "alias": '
#  '"farmboy-market-meats-sandwiches-chandler-2", "name": "Farmboy Market, '
#  'Meats, Sandwiches", "image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/x78bQGzZK6y17lUgUhZJbg/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/farmboy-market-meats-sandwiches-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 108, "categories": [{"alias": "sandwiches", "title": '
#  '"Sandwiches"}, {"alias": "bbq", "title": "Barbeque"}, {"alias": '
#  '"tradamerican", "title": "American (Traditional)"}], "rating": 4.5, '
#  '"coordinates": {"latitude": 33.2616451, "longitude": -111.8634891}, '
#  '"transactions": ["pickup", "delivery"], "price": "$$", "location": '
#  '{"address1": "1075 W Queen Creek Rd", "address2": "Ste 1", "address3": null, '
#  '"city": "Chandler", "zip_code": "85248", "country": "US", "state": "AZ", '
#  '"display_address": ["1075 W Queen Creek Rd", "Ste 1", "Chandler, AZ '
#  '85248"]}, "phone": "+14803612153", "display_phone": "(480) 361-2153", '
#  '"distance": 2681.982036152666}, {"id": "2aeZ9Xm_mjia11jf1pg7QA", "alias": '
#  '"green-corner-restaurant-chandler-3", "name": "Green Corner Restaurant", '
#  '"image_url": '
#  '"https://s3-media4.fl.yelpcdn.com/bphoto/xqHVsN049nZTE5TBk7qTMA/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/green-corner-restaurant-chandler-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 206, "categories": [{"alias": "mediterranean", "title": '
#  '"Mediterranean"}, {"alias": "mideastern", "title": "Middle Eastern"}, '
#  '{"alias": "greek", "title": "Greek"}], "rating": 4.5, "coordinates": '
#  '{"latitude": 33.2616425, "longitude": -111.8635409}, "transactions": '
#  '["pickup", "delivery"], "price": "$$", "location": {"address1": "1065 W '
#  'Queen Creek Rd", "address2": "Ste 2", "address3": null, "city": "Chandler", '
#  '"zip_code": "85248", "country": "US", "state": "AZ", "display_address": '
#  '["1065 W Queen Creek Rd", "Ste 2", "Chandler, AZ 85248"]}, "phone": '
#  '"+14805537011", "display_phone": "(480) 553-7011", "distance": '
#  '2671.59275081591}, {"id": "JGbQOdAAqxEKlyJy07omuw", "alias": '
#  '"civic-market-chandler", "name": "Civic Market", "image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/scSNIth8v2U5-qtlpb2cYQ/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/civic-market-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 15, "categories": [{"alias": "cafes", "title": "Cafes"}], '
#  '"rating": 4.5, "coordinates": {"latitude": 33.3004818489723, "longitude": '
#  '-111.840002909303}, "transactions": [], "location": {"address1": "201 S '
#  'Washington St", "address2": "", "address3": null, "city": "Chandler", '
#  '"zip_code": "85225", "country": "US", "state": "AZ", "display_address": '
#  '["201 S Washington St", "Chandler, AZ 85225"]}, "phone": "", '
#  '"display_phone": "", "distance": 3484.8129626252367}, {"id": '
#  '"-fZ4jE_7FKos0MQvMqoj5Q", "alias": "culinary-dropout-gilbert-4", "name": '
#  '"Culinary Dropout", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/Gse0akUPdo_bFXRo8_1pkQ/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/culinary-dropout-gilbert-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 98, "categories": [{"alias": "newamerican", "title": '
#  '"American (New)"}], "rating": 4.0, "coordinates": {"latitude": 33.3569301, '
#  '"longitude": -111.7895751}, "transactions": [], "price": "$$", "location": '
#  '{"address1": "383 N Gilbert Rd", "address2": "", "address3": null, "city": '
#  '"Gilbert", "zip_code": "85234", "country": "US", "state": "AZ", '
#  '"display_address": ["383 N Gilbert Rd", "Gilbert, AZ 85234"]}, "phone": '
#  '"+14804183980", "display_phone": "(480) 418-3980", "distance": '
#  '10520.835790435194}, {"id": "QwPt--ZmXlSHq_UhUYpIYw", "alias": '
#  '"ghett-yo-taco-chandler", "name": "Ghett Yo Taco", "image_url": '
#  '"https://s3-media4.fl.yelpcdn.com/bphoto/T9fHMIqhzXbcJ61PsPTjZg/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/ghett-yo-taco-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 264, "categories": [{"alias": "tacos", "title": "Tacos"}], '
#  '"rating": 4.0, "coordinates": {"latitude": 33.29987, "longitude": '
#  '-111.84258}, "transactions": ["pickup", "delivery"], "price": "$", '
#  '"location": {"address1": "241 S Oregon St", "address2": "", "address3": '
#  'null, "city": "Chandler", "zip_code": "85225", "country": "US", "state": '
#  '"AZ", "display_address": ["241 S Oregon St", "Chandler, AZ 85225"]}, '
#  '"phone": "+14807269654", "display_phone": "(480) 726-9654", "distance": '
#  '3470.6312648576245}, {"id": "52yWGkwnrQXIjvuMjYxsiA", "alias": '
#  '"not-your-typical-deli-gilbert", "name": "Not Your Typical Deli", '
#  '"image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/RYG8jPlPCtAjGs7PxeyGug/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/not-your-typical-deli-gilbert?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 520, "categories": [{"alias": "delis", "title": "Delis"}, '
#  '{"alias": "sandwiches", "title": "Sandwiches"}, {"alias": "cuban", "title": '
#  '"Cuban"}], "rating": 5.0, "coordinates": {"latitude": 33.328922, '
#  '"longitude": -111.795453}, "transactions": [], "price": "$$", "location": '
#  '{"address1": "1166 South Gilbert Rd", "address2": "Ste 101", "address3": '
#  'null, "city": "Gilbert", "zip_code": "85296", "country": "US", "state": '
#  '"AZ", "display_address": ["1166 South Gilbert Rd", "Ste 101", "Gilbert, AZ '
#  '85296"]}, "phone": "+14807941116", "display_phone": "(480) 794-1116", '
#  '"distance": 7468.977902133951}, {"id": "_H4GXECi4nHfJTz4dsQV_w", "alias": '
#  '"ritas-burritos-chandler", "name": "Rita\'s Burritos", "image_url": '
#  '"https://s3-media1.fl.yelpcdn.com/bphoto/sM7KoOGe_hIGoCaX16gmFw/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/ritas-burritos-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 281, "categories": [{"alias": "mexican", "title": '
#  '"Mexican"}], "rating": 4.5, "coordinates": {"latitude": 33.246637, '
#  '"longitude": -111.84268}, "transactions": ["pickup"], "price": "$", '
#  '"location": {"address1": "4040 S Arizona Ave", "address2": "Ste 17", '
#  '"address3": "", "city": "Chandler", "zip_code": "85248", "country": "US", '
#  '"state": "AZ", "display_address": ["4040 S Arizona Ave", "Ste 17", '
#  '"Chandler, AZ 85248"]}, "phone": "+14804049128", "display_phone": "(480) '
#  '404-9128", "distance": 2704.683918527783}, {"id": "U4OLUFb9VxMmpMXm1ZF-cQ", '
#  '"alias": "pho-chandler-chandler", "name": "Pho Chandler", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/eDW_BuE0jWui79fnJwCqrw/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/pho-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 527, "categories": [{"alias": "vietnamese", "title": '
#  '"Vietnamese"}, {"alias": "chinese", "title": "Chinese"}, {"alias": '
#  '"noodles", "title": "Noodles"}], "rating": 4.5, "coordinates": {"latitude": '
#  '33.24675, "longitude": -111.83921}, "transactions": [], "price": "$", '
#  '"location": {"address1": "4055 S Arizona Ave", "address2": "Ste 8", '
#  '"address3": null, "city": "Chandler", "zip_code": "85248", "country": "US", '
#  '"state": "AZ", "display_address": ["4055 S Arizona Ave", "Ste 8", "Chandler, '
#  'AZ 85248"]}, "phone": "+14808959090", "display_phone": "(480) 895-9090", '
#  '"distance": 2638.4978300426837}, {"id": "dsvLGvwI8Q3PSLWPMBadMw", "alias": '
#  '"st-amand-kitchen-and-cocktails-chandler", "name": "St. Amand Kitchen and '
#  'Cocktails", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/WJG80nfMj-tYssQnD716cw/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/st-amand-kitchen-and-cocktails-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 5, "categories": [{"alias": "cocktailbars", "title": '
#  '"Cocktail Bars"}, {"alias": "newamerican", "title": "American (New)"}], '
#  '"rating": 4.0, "coordinates": {"latitude": 33.2475806926958, "longitude": '
#  '-111.865434303524}, "transactions": [], "location": {"address1": "3990 S '
#  'Alma School Rd", "address2": "", "address3": null, "city": "Chandler", '
#  '"zip_code": "85248", "country": "US", "state": "AZ", "display_address": '
#  '["3990 S Alma School Rd", "Chandler, AZ 85248"]}, "phone": "+14807825550", '
#  '"display_phone": "(480) 782-5550", "distance": 3868.9767259434952}, {"id": '
#  '"Rn2zXbZJab8mPUz8aYdOtQ", "alias": "tryst-cafe-chandler-chandler-2", "name": '
#  '"Tryst Cafe Chandler", "image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/J8j496D1PbqXS6HjZ2Oa-A/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/tryst-cafe-chandler-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 106, "categories": [{"alias": "breakfast_brunch", "title": '
#  '"Breakfast & Brunch"}, {"alias": "newamerican", "title": "American (New)"}], '
#  '"rating": 4.0, "coordinates": {"latitude": 33.2403644482708, "longitude": '
#  '-111.78929276642}, "transactions": ["restaurant_reservation"], "price": '
#  '"$$", "location": {"address1": "4205 S Gilbert Rd", "address2": "", '
#  '"address3": null, "city": "Chandler", "zip_code": "85249", "country": "US", '
#  '"state": "AZ", "display_address": ["4205 S Gilbert Rd", "Chandler, AZ '
#  '85249"]}, "phone": "+14806561011", "display_phone": "(480) 656-1011", '
#  '"distance": 4928.210878992833}, {"id": "HujfG5PyOqn5bPsoxkgSiw", "alias": '
#  '"bkd-backyard-joint-chandler", "name": "BKD Backyard Joint", "image_url": '
#  '"", "is_closed": false, "url": '
#  '"https://www.yelp.com/biz/bkd-backyard-joint-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 1, "categories": [{"alias": "sportsbars", "title": "Sports '
#  'Bars"}, {"alias": "tradamerican", "title": "American (Traditional)"}], '
#  '"rating": 5.0, "coordinates": {"latitude": 33.2932987090176, "longitude": '
#  '-111.824992170089}, "transactions": [], "location": {"address1": "980 E '
#  'Pecos Rd", "address2": "Ste 5", "address3": null, "city": "Chandler", '
#  '"zip_code": "85225", "country": "US", "state": "AZ", "display_address": '
#  '["980 E Pecos Rd", "Ste 5", "Chandler, AZ 85225"]}, "phone": "+14809352537", '
#  '"display_phone": "(480) 935-2537", "distance": 2739.5871327369096}, {"id": '
#  '"HYhbeLznSWEl6JIYTllVUA", "alias": '
#  '"stone-and-vine-urban-italian-chandler-2", "name": "Stone & Vine Urban '
#  'Italian", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/HQNfxs9czSQIlOnbXSaV6w/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/stone-and-vine-urban-italian-chandler-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 378, "categories": [{"alias": "wine_bars", "title": "Wine '
#  'Bars"}, {"alias": "italian", "title": "Italian"}, {"alias": "pizza", '
#  '"title": "Pizza"}], "rating": 4.0, "coordinates": {"latitude": '
#  '33.2608865864458, "longitude": -111.859443623372}, "transactions": '
#  '["restaurant_reservation", "delivery"], "price": "$$", "location": '
#  '{"address1": "1035 W Queen Creek Rd", "address2": "Ste 103", "address3": "", '
#  '"city": "Chandler", "zip_code": "85248", "country": "US", "state": "AZ", '
#  '"display_address": ["1035 W Queen Creek Rd", "Ste 103", "Chandler, AZ '
#  '85248"]}, "phone": "+14806597438", "display_phone": "(480) 659-7438", '
#  '"distance": 2621.6555403207935}, {"id": "kDo4Lu9V3EKJ0QXzIQ1t0w", "alias": '
#  '"sashas-kitchen-and-cocktails-chandler", "name": "Sasha\'s Kitchen & '
#  'Cocktails", "image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/TD1mFz9Fb0HBSbepnKL15w/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/sashas-kitchen-and-cocktails-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 281, "categories": [{"alias": "cocktailbars", "title": '
#  '"Cocktail Bars"}, {"alias": "newamerican", "title": "American (New)"}], '
#  '"rating": 4.0, "coordinates": {"latitude": 33.30201, "longitude": '
#  '-111.84242}, "transactions": ["pickup", "restaurant_reservation", '
#  '"delivery"], "price": "$$", "location": {"address1": "81 W Boston St", '
#  '"address2": null, "address3": "", "city": "Chandler", "zip_code": "85225", '
#  '"country": "US", "state": "AZ", "display_address": ["81 W Boston St", '
#  '"Chandler, AZ 85225"]}, "phone": "+14802847447", "display_phone": "(480) '
#  '284-7447", "distance": 3696.7979679634295}, {"id": "1GXTRFzsANkhkRIivqMtuQ", '
#  '"alias": "the-local-chandler-chandler", "name": "The Local Chandler", '
#  '"image_url": '
#  '"https://s3-media3.fl.yelpcdn.com/bphoto/9OOWfQySPRlay9-c0QwGxg/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/the-local-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 157, "categories": [{"alias": "sportsbars", "title": "Sports '
#  'Bars"}, {"alias": "tradamerican", "title": "American (Traditional)"}, '
#  '{"alias": "tacos", "title": "Tacos"}], "rating": 4.0, "coordinates": '
#  '{"latitude": 33.3004263644627, "longitude": -111.842268034816}, '
#  '"transactions": [], "price": "$$", "location": {"address1": "55 W Chicago '
#  'St", "address2": "", "address3": null, "city": "Chandler", "zip_code": '
#  '"85225", "country": "US", "state": "AZ", "display_address": ["55 W Chicago '
#  'St", "Chandler, AZ 85225"]}, "phone": "+14806999104", "display_phone": '
#  '"(480) 699-9104", "distance": 3522.732729303816}, {"id": '
#  '"x4WNvN5wtMb8KVvYZOsLag", "alias": "grubstak-chandler-chandler", "name": '
#  '"Grubstak - Chandler", "image_url": '
#  '"https://s3-media2.fl.yelpcdn.com/bphoto/g1MPTR5lf1WeNelPlLDyFw/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/grubstak-chandler-chandler?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 66, "categories": [{"alias": "newamerican", "title": '
#  '"American (New)"}, {"alias": "breakfast_brunch", "title": "Breakfast & '
#  'Brunch"}, {"alias": "comfortfood", "title": "Comfort Food"}], "rating": 4.5, '
#  '"coordinates": {"latitude": 33.2405529, "longitude": -111.7892151}, '
#  '"transactions": [], "price": "$$", "location": {"address1": "4165 S Gilbert '
#  'Rd", "address2": "Ste 5", "address3": "", "city": "Chandler", "zip_code": '
#  '"85249", "country": "US", "state": "AZ", "display_address": ["4165 S Gilbert '
#  'Rd", "Ste 5", "Chandler, AZ 85249"]}, "phone": "+14804543299", '
#  '"display_phone": "(480) 454-3299", "distance": 4853.628201745834}, {"id": '
#  '"WHiND6UPxr6WzgGhz2E91Q", "alias": "hash-kitchen-chandler-4", "name": "Hash '
#  'Kitchen", "image_url": '
#  '"https://s3-media4.fl.yelpcdn.com/bphoto/CCUI5nU8JFcSQ6SAJCJApQ/o.jpg", '
#  '"is_closed": false, "url": '
#  '"https://www.yelp.com/biz/hash-kitchen-chandler-4?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw", '
#  '"review_count": 865, "categories": [{"alias": "breakfast_brunch", "title": '
#  '"Breakfast & Brunch"}], "rating": 4.5, "coordinates": {"latitude": '
#  '33.3199317579525, "longitude": -111.890247389674}, "transactions": [], '
#  '"price": "$$", "location": {"address1": "2855 W Ray Rd", "address2": "Ste '
#  '3", "address3": null, "city": "Chandler", "zip_code": "85224", "country": '
#  '"US", "state": "AZ", "display_address": ["2855 W Ray Rd", "Ste 3", '
#  '"Chandler, AZ 85224"]}, "phone": "+14809094270", "display_phone": "(480) '
#  '909-4270", "distance": 7700.913701367345}], "total": 2700, "region": '
#  '{"center": {"longitude": -111.83326721191406, "latitude": '
#  '33.26965211363515}}}')
