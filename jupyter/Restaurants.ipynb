# %%
import requests
import json

# %%
api_key='1bH1i6hqL0TXbaFy8Jm4O7O5brL-iPCC5-0MvC_Wm18KDkFM0vD51t7EuuSfZeQF_i2FxDSZFwUZBP2mCsV9McVCUustTrkIGVISF4p-ZJLkwLL_XY_lEhLmeBzaXHYx'
headers = {'Authorization': 'Bearer %s' % api_key}

# %%
url='https://api.yelp.com/v3/businesses/search'

# In the dictionary, term can take values like food, cafes or businesses like McDonalds
params = {'term':'breakfast','location':'85029'}

# %%
# Making a get request to the API
req=requests.get(url, params=params, headers=headers)
 
# proceed only if the status code is 200
print('The status code is {}'.format(req.status_code))
# Out:
# The status code is 200

# %%
# printing the text from the response 
json.loads(req.text)
# Out:
# {'businesses': [{'id': 'hH8002bWtOFYtLgarFZBsg',
#    'alias': 'first-watch-phoenix-18',
#    'name': 'First Watch',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EWtpexjzGWekiXzcaIzw9A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/first-watch-phoenix-18?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 448,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.5745287027062,
#     'longitude': -112.116308406082},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9645 N Black Canyon Hwy',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85021',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['9645 N Black Canyon Hwy', 'Phoenix, AZ 85021']},
#    'phone': '+16029433232',
#    'display_phone': '(602) 943-3232',
#    'distance': 2018.3329151875523},
#   {'id': 'E4JyAzB5_2quptwtemyhYA',
#    'alias': 'original-breakfast-house-phoenix',
#    'name': 'Original Breakfast House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b4QMOwXWqCrgEDenBg128w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/original-breakfast-house-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 1554,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.6108041847228,
#     'longitude': -112.012835965607},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '13623 N 32nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85032',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['13623 N 32nd St', 'Phoenix, AZ 85032']},
#    'phone': '+16024822328',
#    'display_phone': '(602) 482-2328',
#    'distance': 9042.723233984862},
#   {'id': '8Zqh2jwtncA3N4fWEMTvZQ',
#    'alias': 'scramble-a-breakfast-joint-phoenix',
#    'name': 'Scramble A Breakfast Joint',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/gCNq_c00lz7MgpKL8JSncQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/scramble-a-breakfast-joint-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 871,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.5758653, 'longitude': -112.0653049},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9832 N 7th St',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85020',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['9832 N 7th St', 'Ste 1', 'Phoenix, AZ 85020']},
#    'phone': '+16023742294',
#    'display_phone': '(602) 374-2294',
#    'distance': 4227.1927623429965},
#   {'id': 'woP-omtF0PobX4JxXpZa7Q',
#    'alias': 'ronnies-cafe-glendale',
#    'name': "Ronnie's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/diSS8ldJ26cm8kWyWVZ8Xw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ronnies-cafe-glendale?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 367,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.595588684082,
#     'longitude': -112.152214050293},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4323 W Cactus Rd',
#     'address2': 'Ste 3',
#     'address3': None,
#     'city': 'Glendale',
#     'zip_code': '85304',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4323 W Cactus Rd', 'Ste 3', 'Glendale, AZ 85304']},
#    'phone': '+16025485857',
#    'display_phone': '(602) 548-5857',
#    'distance': 4186.929881145585},
#   {'id': 'jCY_nUGmElQsERJsovVEDQ',
#    'alias': 'the-cracked-egg-phoenix',
#    'name': 'The Cracked Egg',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ywIZUM_zS6Jd1KCwhgKgbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cracked-egg-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 286,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.5388426, 'longitude': -112.1326376},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3422 W Glendale Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85051',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['3422 W Glendale Ave', 'Phoenix, AZ 85051']},
#    'phone': '+16022422288',
#    'display_phone': '(602) 242-2288',
#    'distance': 6263.590025553228},
#   {'id': 'fOnpoMXToa5Qiyg95E6ENg',
#    'alias': 'mike-and-rondas-the-place-glendale',
#    'name': "Mike and Ronda's The Place",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/07oq4aOtBRET2_hsQ6rxkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mike-and-rondas-the-place-glendale?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 712,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6386733385579,
#     'longitude': -112.170983787708},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '5171 W Bell Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '85308',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['5171 W Bell Rd', 'Glendale, AZ 85308']},
#    'phone': '+16028969929',
#    'display_phone': '(602) 896-9929',
#    'distance': 7898.152599158148},
#   {'id': 'utIA0LyQmwP-9DRyxUe6qQ',
#    'alias': 'snooze-an-a-m-eatery-phoenix-3',
#    'name': 'Snooze, An A.M. Eatery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/seiDlCIy5ATf53JlEawhRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snooze-an-a-m-eatery-phoenix-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 1386,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.5082039543161,
#     'longitude': -112.037033047614},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2045 E Camelback Rd',
#     'address2': 'Ste A17',
#     'address3': 'Town and Country',
#     'city': 'Phoenix',
#     'zip_code': '85016',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2045 E Camelback Rd',
#      'Ste A17',
#      'Town and Country',
#      'Phoenix, AZ 85016']},
#    'phone': '+14807258000',
#    'display_phone': '(480) 725-8000',
#    'distance': 11306.267062077186},
#   {'id': '5qEMfUERdTcMk7aDwH3A_Q',
#    'alias': 'candys-kitchen-phoenix',
#    'name': "Candy's Kitchen",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VyFnsQxxfpsA3E-Rz52Tjg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candys-kitchen-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 118,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.60597, 'longitude': -112.06634},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '13216 N 7th St',
#     'address2': 'Ste 34',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85022',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['13216 N 7th St', 'Ste 34', 'Phoenix, AZ 85022']},
#    'phone': '+16023689897',
#    'display_phone': '(602) 368-9897',
#    'distance': 4158.269746454688},
#   {'id': 'IdNMRM2U4GK7zbsD7R2BWA',
#    'alias': 'u-s-egg-phoenix-11',
#    'name': 'US Egg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9NQ00rmTd82KjnB5jz9stQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-s-egg-phoenix-11?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 248,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'waffles', 'title': 'Waffles'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.6396451, 'longitude': -112.122932},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2957 W Bell Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85053',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2957 W Bell Rd', 'Phoenix, AZ 85053']},
#    'phone': '+16028431249',
#    'display_phone': '(602) 843-1249',
#    'distance': 5560.789814848025},
#   {'id': '24Td_CQH1bonWKff1rt2vg',
#    'alias': 'matts-big-breakfast-phoenix-5',
#    'name': "Matt's Big Breakfast",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WO-SrPVJDDhAWojaEoQbiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/matts-big-breakfast-phoenix-5?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 371,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.5110320562809,
#     'longitude': -112.015278849925},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3118 E Camelback Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85016',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['3118 E Camelback Rd', 'Phoenix, AZ 85016']},
#    'phone': '+16028403450',
#    'display_phone': '(602) 840-3450',
#    'distance': 12351.147980348764},
#   {'id': 'Lm61pehc-oyqR6DBAAQNCg',
#    'alias': 'kiss-the-cook-restaurant-glendale',
#    'name': 'Kiss the Cook Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QdBZbKsgUaxweDb8aZPRmg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kiss-the-cook-restaurant-glendale?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 372,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.53807, 'longitude': -112.16561},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4915 W Glendale Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Glendale',
#     'zip_code': '85301',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4915 W Glendale Ave', 'Glendale, AZ 85301']},
#    'phone': '+16239394663',
#    'display_phone': '(623) 939-4663',
#    'distance': 7971.173763795921},
#   {'id': 'SxelcKtJlN6X2Vlak0wXHw',
#    'alias': 'mi-pueblo-phoenix',
#    'name': 'Mi Pueblo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/GHfOoBUTY4gqZLQpW6UGsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mi-pueblo-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 184,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.5741241532692,
#     'longitude': -112.125614583492},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '9620 N Metro Pkwy W',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85051',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['9620 N Metro Pkwy W', 'Phoenix, AZ 85051']},
#    'phone': '+16028702953',
#    'display_phone': '(602) 870-2953',
#    'distance': 2525.6693792922297},
#   {'id': 'A6qLlVs7kR8fxlZmQ_Zecw',
#    'alias': 'metro-cafe-phoenix',
#    'name': 'Metro Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fbyIbFignsEVlBFOaMse9g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/metro-cafe-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'wraps', 'title': 'Wraps'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 33.5772401140408,
#     'longitude': -112.127021995893},
#    'transactions': [],
#    'location': {'address1': '10000 N 31st Ave',
#     'address2': 'Ste A106',
#     'address3': None,
#     'city': 'Phoenix',
#     'zip_code': '85051',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['10000 N 31st Ave', 'Ste A106', 'Phoenix, AZ 85051']},
#    'phone': '+16022186340',
#    'display_phone': '(602) 218-6340',
#    'distance': 2374.613474882067},
#   {'id': 'S_bG5WWbtNXhhY9Y0GTcSg',
#    'alias': 'fàme-caffe-phoenix-2',
#    'name': 'Fàme Caffe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/toXSXt3jU0Y3dBJmUK6-bA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/f%C3%A0me-caffe-phoenix-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 532,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.5058546659985,
#     'longitude': -112.074009924076},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '4700 N Central Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85012',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['4700 N Central Ave', 'Phoenix, AZ 85012']},
#    'phone': '+16023144660',
#    'display_phone': '(602) 314-4660',
#    'distance': 9982.771847199621},
#   {'id': 'QxoEkFbKsmpPrzPpWGfJgg',
#    'alias': 'lucky-donuts-phoenix',
#    'name': 'Lucky Donuts',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2YNKGxICpnSoVjG_TE4TtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucky-donuts-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 122,
#    'categories': [{'alias': 'donuts', 'title': 'Donuts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.611213, 'longitude': -112.110114},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2510 W Thunderbird Rd',
#     'address2': 'Ste 1',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85023',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2510 W Thunderbird Rd',
#      'Ste 1',
#      'Phoenix, AZ 85023']},
#    'phone': '+16024392057',
#    'display_phone': '(602) 439-2057',
#    'distance': 2242.0162737224064},
#   {'id': 'cLeH08WoBoozrRco89i9Nw',
#    'alias': 'lets-do-lunch-phoenix-3',
#    'name': "Let's Do Lunch",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8k7RxT4co4EG5ZZOqO_oSQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lets-do-lunch-phoenix-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 15,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.58321, 'longitude': -112.10886},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '2320 W Peoria Ave',
#     'address2': 'Ste A107',
#     'address3': None,
#     'city': 'Phoenix',
#     'zip_code': '85029',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['2320 W Peoria Ave', 'Ste A107', 'Phoenix, AZ 85029']},
#    'phone': '+16029439475',
#    'display_phone': '(602) 943-9475',
#    'distance': 894.9853146002478},
#   {'id': 'PW3EHPvjc3lsnncvx40Y7g',
#    'alias': 'dos-arboles-restaurant-and-cantina-phoenix-3',
#    'name': 'dos arboles Restaurant & Cantina',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fwN7itvDa1gtZ_OO3cUV5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dos-arboles-restaurant-and-cantina-phoenix-3?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 4,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 33.57908, 'longitude': -112.11998},
#    'transactions': [],
#    'location': {'address1': '10220 N Metro Pkwy E',
#     'address2': '',
#     'address3': None,
#     'city': 'Phoenix',
#     'zip_code': '85051',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['10220 N Metro Pkwy E', 'Phoenix, AZ 85051']},
#    'phone': '+16029975900',
#    'display_phone': '(602) 997-5900',
#    'distance': 1783.6096093792091},
#   {'id': 'bVqNtwcwIz2gAacHWYF2lw',
#    'alias': 'moon-valley-cafe-phoenix-2',
#    'name': 'Moon Valley Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wUdqjJhX91SyEMIR137LCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moon-valley-cafe-phoenix-2?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 151,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 33.607839, 'longitude': -112.0671394},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '502 E Thunderbird Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85022',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['502 E Thunderbird Rd', 'Phoenix, AZ 85022']},
#    'phone': '+16023750445',
#    'display_phone': '(602) 375-0445',
#    'distance': 4253.563604495579},
#   {'id': '_O2_jwNT_3FDaSRZ50jvrw',
#    'alias': 'the-joy-bus-diner-phoenix',
#    'name': 'The Joy Bus Diner',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/sowQbSjDWxiuqWJ8hzWY_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-joy-bus-diner-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 206,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'nonprofit', 'title': 'Community Service/Non-Profit'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.5820979, 'longitude': -112.0086535},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3375 E Shea Blvd',
#     'address2': 'C1',
#     'address3': None,
#     'city': 'Phoenix',
#     'zip_code': '85028',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['3375 E Shea Blvd', 'C1', 'Phoenix, AZ 85028']},
#    'phone': '+16025955884',
#    'display_phone': '(602) 595-5884',
#    'distance': 9219.08363643635},
#   {'id': 'jsuUmIEefPjV__ads62Z5w',
#    'alias': 'dicks-hideaway-phoenix',
#    'name': "Dick's Hideaway",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xd3Zufj5QZo97bHbhuTlsw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dicks-hideaway-phoenix?adjust_creative=4cZOEmy0F0zv75cCIb5XJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=4cZOEmy0F0zv75cCIb5XJw',
#    'review_count': 939,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'newmexican', 'title': 'New Mexican Cuisine'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 33.5241701058918,
#     'longitude': -112.047840593918},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '6008 N 16th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Phoenix',
#     'zip_code': '85014',
#     'country': 'US',
#     'state': 'AZ',
#     'display_address': ['6008 N 16th St', 'Phoenix, AZ 85014']},
#    'phone': '+16022411881',
#    'display_phone': '(602) 241-1881',
#    'distance': 9280.745792724176}],
#  'total': 676,
#  'region': {'center': {'longitude': -112.10758209228516,
#    'latitude': 33.59116062683965}}}
