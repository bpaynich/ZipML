# %%
import requests
import json
import xmltodict
import pandas as pd
from config import api

# %%
zipcode= pd.read_csv('free-zipcode-database.csv')
zipcode_df= pd.DataFrame(zipcode, columns=['RecordNumber', 'Zipcode', 'City', 'State'])
zipcode_df.head()
# Out:
# C:\Users\diana\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    RecordNumber  Zipcode                 City State
# 0             1      704          PARC PARQUE    PR
# 1             2      704  PASEO COSTA DEL SUR    PR
# 2             3      704        SECT LANAUSSE    PR
# 3             4      704      URB EUGENE RICE    PR
# 4             5      704         URB GONZALEZ    PR

# %%
zipcode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81831 entries, 0 to 81830
# Data columns (total 4 columns):
# RecordNumber    81831 non-null int64
# Zipcode         81831 non-null int64
# City            81831 non-null object
# State           81831 non-null object
# dtypes: int64(2), object(2)
# memory usage: 2.5+ MB

# %%
zip_code = 85016

for i, j in zipcode_df.iterrows():
#     ZIP = zipcode_df.iloc[i, 1]
#     print(ZIP)
    if zip_code == zipcode_df.iloc[i, 1]:
        state= zipcode_df.iloc[i, 3]
        city = zipcode_df.iloc[i, 2]
        print(f'zipcode: {zipcode_df.iloc[i, 1]}, city: {city} , state: {state}')
    i+=1
# Out:
# zipcode: 85016, city: PHOENIX , state: AZ

# %%
# Prepare for API call
base_url = "https://www.zillow.com/webservice/GetRegionChildren.htm?"
zws_id=api
state=state
city=city
childtype="zipcode"


query_url = f"{base_url}zws-id={zws_id}&state={state}&city={city}&childtype={childtype}"
print(f"Processing: {query_url}")
# Out:
# Processing: https://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz1h2w2gwiznv_55f1z&state=AZ&city=PHOENIX&childtype=zipcode

# %%
# import xmltodict

data = requests.get(query_url)
xpars = xmltodict.parse(data.text)
json_data = json.dumps(xpars, sort_keys=True, indent=4)
print(json_data)
# Out:
# {
#     "RegionChildren:regionchildren": {
#         "@xmlns:RegionChildren": "http://www.zillow.com/static/xsd/RegionChildren.xsd",
#         "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#         "@xsi:schemaLocation": "http://www.zillow.com/static/xsd/RegionChildren.xsd https://www.zillowstatic.com/vstatic/80d5e73/static/xsd/RegionChildren.xsd",
#         "message": {
#             "code": "0",
#             "text": "Request successfully processed"
#         },
#         "request": {
#             "childtype": "zipcode",
#             "city": "PHOENIX",
#             "state": "AZ"
#         },
#         "response": {
#             "list": {
#                 "count": "77",
#                 "region": [
#                     {
#                         "id": "94748",
#                         "latitude": "33.624433",
#                         "longitude": "-112.004795",
#                         "name": "85032",
#                         "zindex": {
#                             "#text": "197200",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94738",
#                         "latitude": "33.625325",
#                         "longitude": "-112.053375",
#                         "name": "85022",
#                         "zindex": {
#                             "#text": "216100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94724",
#                         "latitude": "33.46289",
#                         "longitude": "-111.984926",
#                         "name": "85008",
#                         "zindex": {
#                             "#text": "121000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94732",
#                         "latitude": "33.515471",
#                         "longitude": "-112.031483",
#                         "name": "85016",
#                         "zindex": {
#                             "#text": "224200",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94734",
#                         "latitude": "33.51509",
#                         "longitude": "-111.981672",
#                         "name": "85018",
#                         "zindex": {
#                             "#text": "379700",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94760",
#                         "latitude": "33.34175",
#                         "longitude": "-111.991931",
#                         "name": "85044",
#                         "zindex": {
#                             "#text": "245100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94745",
#                         "latitude": "33.591183",
#                         "longitude": "-112.107603",
#                         "name": "85029",
#                         "zindex": {
#                             "#text": "142600",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94757",
#                         "latitude": "33.382387",
#                         "longitude": "-112.119948",
#                         "name": "85041",
#                         "zindex": {
#                             "#text": "133100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94736",
#                         "latitude": "33.572208",
#                         "longitude": "-112.054839",
#                         "name": "85020",
#                         "zindex": {
#                             "#text": "162600",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94737",
#                         "latitude": "33.521917",
#                         "longitude": "-112.134195",
#                         "name": "85021",
#                         "zindex": {
#                             "#text": "195000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94743",
#                         "latitude": "33.681811",
#                         "longitude": "-112.092914",
#                         "name": "85027",
#                         "zindex": {
#                             "#text": "160900",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94731",
#                         "latitude": "33.509093",
#                         "longitude": "-112.101516",
#                         "name": "85015",
#                         "zindex": {
#                             "#text": "134500",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94765",
#                         "latitude": "33.534777",
#                         "longitude": "-112.109368",
#                         "name": "85051",
#                         "zindex": {
#                             "#text": "130200",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94749",
#                         "latitude": "33.492008",
#                         "longitude": "-112.208054",
#                         "name": "85033"
#                     },
#                     {
#                         "id": "94792",
#                         "latitude": "33.817803",
#                         "longitude": "-112.133183",
#                         "name": "85086",
#                         "zindex": {
#                             "#text": "302400",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94751",
#                         "latitude": "33.471377",
#                         "longitude": "-112.195003",
#                         "name": "85035"
#                     },
#                     {
#                         "id": "94758",
#                         "latitude": "33.361321",
#                         "longitude": "-112.037496",
#                         "name": "85042",
#                         "zindex": {
#                             "#text": "138800",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94739",
#                         "latitude": "33.631063",
#                         "longitude": "-112.094295",
#                         "name": "85023",
#                         "zindex": {
#                             "#text": "190900",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94753",
#                         "latitude": "33.492305",
#                         "longitude": "-112.28078",
#                         "name": "85037",
#                         "zindex": {
#                             "#text": "128900",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94915",
#                         "latitude": "33.262733",
#                         "longitude": "-112.178415",
#                         "name": "85339",
#                         "zindex": {
#                             "#text": "185600",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94763",
#                         "latitude": "33.281245",
#                         "longitude": "-112.036796",
#                         "name": "85048",
#                         "zindex": {
#                             "#text": "307000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94730",
#                         "latitude": "33.507435",
#                         "longitude": "-112.058454",
#                         "name": "85014",
#                         "zindex": {
#                             "#text": "164000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94725",
#                         "latitude": "33.443624",
#                         "longitude": "-112.131538",
#                         "name": "85009"
#                     },
#                     {
#                         "id": "94764",
#                         "latitude": "33.689992",
#                         "longitude": "-111.999951",
#                         "name": "85050",
#                         "zindex": {
#                             "#text": "292400",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94733",
#                         "latitude": "33.507717",
#                         "longitude": "-112.127532",
#                         "name": "85017"
#                     },
#                     {
#                         "id": "94766",
#                         "latitude": "33.629303",
#                         "longitude": "-112.13321",
#                         "name": "85053",
#                         "zindex": {
#                             "#text": "159100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94740",
#                         "latitude": "33.688926",
#                         "longitude": "-112.045772",
#                         "name": "85024",
#                         "zindex": {
#                             "#text": "225200",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94729",
#                         "latitude": "33.50893",
#                         "longitude": "-112.082536",
#                         "name": "85013",
#                         "zindex": {
#                             "#text": "215000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94756",
#                         "latitude": "33.409641",
#                         "longitude": "-112.030225",
#                         "name": "85040"
#                     },
#                     {
#                         "id": "94791",
#                         "latitude": "33.751988",
#                         "longitude": "-112.076716",
#                         "name": "85085",
#                         "zindex": {
#                             "#text": "316100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94722",
#                         "latitude": "33.464305",
#                         "longitude": "-112.048193",
#                         "name": "85006"
#                     },
#                     {
#                         "id": "94759",
#                         "latitude": "33.431074",
#                         "longitude": "-112.195525",
#                         "name": "85043",
#                         "zindex": {
#                             "#text": "135500",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94744",
#                         "latitude": "33.534039",
#                         "longitude": "-112.114007",
#                         "name": "85028",
#                         "zindex": {
#                             "#text": "323400",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94747",
#                         "latitude": "33.494538",
#                         "longitude": "-112.168132",
#                         "name": "85031"
#                     },
#                     {
#                         "id": "94735",
#                         "latitude": "33.508686",
#                         "longitude": "-112.142868",
#                         "name": "85019"
#                     },
#                     {
#                         "id": "399652",
#                         "latitude": "33.755169",
#                         "longitude": "-112.160598",
#                         "name": "85083",
#                         "zindex": {
#                             "#text": "315900",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94723",
#                         "latitude": "33.445734",
#                         "longitude": "-112.089754",
#                         "name": "85007"
#                     },
#                     {
#                         "id": "94720",
#                         "latitude": "33.450776",
#                         "longitude": "-112.071442",
#                         "name": "85004",
#                         "zindex": {
#                             "#text": "212700",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94719",
#                         "latitude": "33.453643",
#                         "longitude": "-112.07834",
#                         "name": "85003",
#                         "zindex": {
#                             "#text": "295000",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94767",
#                         "latitude": "33.689874",
#                         "longitude": "-111.951766",
#                         "name": "85054",
#                         "zindex": {
#                             "#text": "363700",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94728",
#                         "latitude": "33.508387",
#                         "longitude": "-112.071591",
#                         "name": "85012",
#                         "zindex": {
#                             "#text": "370200",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94761",
#                         "latitude": "33.277989",
#                         "longitude": "-112.113787",
#                         "name": "85045",
#                         "zindex": {
#                             "#text": "363100",
#                             "@currency": "USD"
#                         }
#                     },
#                     {
#                         "id": "94750",
#                         "latitude": "33.431698",
#                         "longitude": "-112.015243",
#                         "name": "85034"
#                     },
#                     {
#                         "id": "94773",
#                         "latitude": "33.509805",
#                         "longitude": "-112.038801",
#                         "name": "85064"
#                     },
#                     {
#                         "id": "94789",
#                         "latitude": "33.655407",
#                         "longitude": "-112.10079",
#                         "name": "85080"
#                     },
#                     {
#                         "id": "94790",
#                         "latitude": "33.449991",
#                         "longitude": "-111.976125",
#                         "name": "85082"
#                     },
#                     {
#                         "id": "94778",
#                         "latitude": "33.555702",
#                         "longitude": "-112.1121",
#                         "name": "85069"
#                     },
#                     {
#                         "id": "94772",
#                         "latitude": "33.501458",
#                         "longitude": "-112.172692",
#                         "name": "85063"
#                     },
#                     {
#                         "id": "94775",
#                         "latitude": "33.389999",
#                         "longitude": "-112.069999",
#                         "name": "85066"
#                     },
#                     {
#                         "id": "94777",
#                         "latitude": "33.575032",
#                         "longitude": "-112.065158",
#                         "name": "85068"
#                     },
#                     {
#                         "id": "94785",
#                         "latitude": "33.34716",
#                         "longitude": "-111.97538",
#                         "name": "85076"
#                     },
#                     {
#                         "id": "94762",
#                         "latitude": "33.626275",
#                         "longitude": "-112.019819",
#                         "name": "85046"
#                     },
#                     {
#                         "id": "94780",
#                         "latitude": "33.596685",
#                         "longitude": "-112.099667",
#                         "name": "85071"
#                     },
#                     {
#                         "id": "94769",
#                         "latitude": "33.480485",
#                         "longitude": "-111.997193",
#                         "name": "85060"
#                     },
#                     {
#                         "id": "94717",
#                         "latitude": "33.453781",
#                         "longitude": "-112.07388",
#                         "name": "85001"
#                     },
#                     {
#                         "id": "94721",
#                         "latitude": "33.447658",
#                         "longitude": "-112.134568",
#                         "name": "85005"
#                     },
#                     {
#                         "id": "94752",
#                         "latitude": "33.480985",
#                         "longitude": "-111.996521",
#                         "name": "85036"
#                     },
#                     {
#                         "id": "94787",
#                         "latitude": "33.626275",
#                         "longitude": "-112.019819",
#                         "name": "85078"
#                     },
#                     {
#                         "id": "94727",
#                         "latitude": "33.505532",
#                         "longitude": "-112.064398",
#                         "name": "85011"
#                     },
#                     {
#                         "id": "94776",
#                         "latitude": "33.493205",
#                         "longitude": "-112.08333",
#                         "name": "85067"
#                     },
#                     {
#                         "id": "94770",
#                         "latitude": "33.509401",
#                         "longitude": "-112.117701",
#                         "name": "85061"
#                     },
#                     {
#                         "id": "94783",
#                         "latitude": "33.436749",
#                         "longitude": "-112.051125",
#                         "name": "85074"
#                     },
#                     {
#                         "id": "94726",
#                         "latitude": "33.465813",
#                         "longitude": "-112.024487",
#                         "name": "85010"
#                     },
#                     {
#                         "id": "94788",
#                         "latitude": "33.509401",
#                         "longitude": "-112.117701",
#                         "name": "85079"
#                     },
#                     {
#                         "id": "94779",
#                         "latitude": "33.293311",
#                         "longitude": "-112.063526",
#                         "name": "85070"
#                     },
#                     {
#                         "id": "94718",
#                         "latitude": "33.453781",
#                         "longitude": "-112.07388",
#                         "name": "85002"
#                     },
#                     {
#                         "id": "94746",
#                         "latitude": "33.453781",
#                         "longitude": "-112.07388",
#                         "name": "85030"
#                     },
#                     {
#                         "id": "94741",
#                         "latitude": "33.498414",
#                         "longitude": "-112.027518",
#                         "name": "85025"
#                     },
#                     {
#                         "id": "94771",
#                         "latitude": "33.45",
#                         "longitude": "-111.97",
#                         "name": "85062"
#                     },
#                     {
#                         "id": "94754",
#                         "latitude": "33.45",
#                         "longitude": "-111.97",
#                         "name": "85038"
#                     },
#                     {
#                         "id": "94755",
#                         "latitude": "33.499999",
#                         "longitude": "-112.29",
#                         "name": "85039"
#                     },
#                     {
#                         "id": "94774",
#                         "latitude": "33.45",
#                         "longitude": "-112.069999",
#                         "name": "85065"
#                     },
#                     {
#                         "id": "94781",
#                         "latitude": "33.45",
#                         "longitude": "-111.97",
#                         "name": "85072"
#                     },
#                     {
#                         "id": "94782",
#                         "latitude": "33.45",
#                         "longitude": "-112.069999",
#                         "name": "85073"
#                     },
#                     {
#                         "id": "94794",
#                         "latitude": "33.436333",
#                         "longitude": "-112.141449",
#                         "name": "85098"
#                     },
#                     {
#                         "id": "94742",
#                         "latitude": "33.480961",
#                         "longitude": "-111.996505",
#                         "name": "85026"
#                     },
#                     {
#                         "id": "94784",
#                         "latitude": "33.45",
#                         "longitude": "-112.069999",
#                         "name": "85075"
#                     }
#                 ]
#             },
#             "region": {
#                 "id": "40326",
#                 "latitude": "33.605414",
#                 "longitude": "-112.12505"
#             },
#             "subregiontype": "zipcode"
#         }
#     }
# }
